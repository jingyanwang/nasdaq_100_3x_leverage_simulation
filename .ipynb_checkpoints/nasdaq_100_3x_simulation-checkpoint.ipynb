# %%
# %run setting.ipynb

# %%
import os
import re
import pandas as pd
import yfinance as yf

# %%
# pip install -U scikit-learn

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import plotly.express as px

# %% [markdown]
# # configuration

# %%
leverage_ratio = 3

ETF = "^NDX"
ETF_3x = 'TQQQ'

# %% [markdown]
# # data loading

# %% [markdown]
# ## QQQ

# %%
qqq = yf.Ticker(ETF).history(
    period="max",
    interval="1d",
    auto_adjust=True,   # <-- IMPORTANT
    actions=False
)

# %%
qqq
# Out:
#                                    Open          High           Low  \
# Date
# 1985-10-01 00:00:00-04:00    110.620003    112.160004    110.565002
# 1985-10-02 00:00:00-04:00    112.139999    112.540001    110.779999
# 1985-10-03 00:00:00-04:00    110.839996    111.184998    110.120003
# 1985-10-04 00:00:00-04:00    110.870003    110.870003    109.855003
# 1985-10-07 00:00:00-04:00    110.074997    110.135002    108.175003
# ...                                 ...           ...           ...
# 2026-02-12 00:00:00-05:00  25261.330078  25310.560547  24643.730469
# 2026-02-13 00:00:00-05:00  24662.949219  24921.470703  24514.960938
# 2026-02-17 00:00:00-05:00  24567.539062  24818.300781  24387.470703
# 2026-02-18 00:00:00-05:00  24744.880859  25057.210938  24696.830078
# 2026-02-19 00:00:00-05:00  24771.652344  24890.117188  24690.869141
#
#                                   Close      Volume
# Date
# 1985-10-01 00:00:00-04:00    112.139999   153160000
# 1985-10-02 00:00:00-04:00    110.824997   164640000
# 1985-10-03 00:00:00-04:00    110.870003   147300000
# 1985-10-04 00:00:00-04:00    110.074997   147900000
# 1985-10-07 00:00:00-04:00    108.199997   128640000
# ...                                 ...         ...
# 2026-02-12 00:00:00-05:00  24687.609375  8855290000
# 2026-02-13 00:00:00-05:00  24732.730469  7964830000
# 2026-02-17 00:00:00-05:00  24701.599609  7654300000
# 2026-02-18 00:00:00-05:00  24898.869141  7705590000
# 2026-02-19 00:00:00-05:00  24797.339844  1031364000
#
# [10175 rows x 5 columns]

# %%
ETF = ETF.replace('^', '')

# %% [markdown]
# qqq =  pd.read_csv(f'^NDX.csv', )

# %%
qqq = qqq.reset_index()
qqq['id'] = qqq.index
qqq['Date'] = pd.to_datetime(qqq['Date']).dt.date

# %%
qqq.to_sql(
name='qqq', 
con = conn,
if_exists='replace', 
index=False,
)
# Out:
# 10175

# %%
df = sql(u"""
select * 
from qqq
order by Date asc
""")

# %%
qqq
# Out:
#              Date          Open          High           Low         Close  \
# 0      1985-10-01    110.620003    112.160004    110.565002    112.139999
# 1      1985-10-02    112.139999    112.540001    110.779999    110.824997
# 2      1985-10-03    110.839996    111.184998    110.120003    110.870003
# 3      1985-10-04    110.870003    110.870003    109.855003    110.074997
# 4      1985-10-07    110.074997    110.135002    108.175003    108.199997
# ...           ...           ...           ...           ...           ...
# 10170  2026-02-12  25261.330078  25310.560547  24643.730469  24687.609375
# 10171  2026-02-13  24662.949219  24921.470703  24514.960938  24732.730469
# 10172  2026-02-17  24567.539062  24818.300781  24387.470703  24701.599609
# 10173  2026-02-18  24744.880859  25057.210938  24696.830078  24898.869141
# 10174  2026-02-19  24771.652344  24890.117188  24690.869141  24797.339844
#
#            Volume     id
# 0       153160000      0
# 1       164640000      1
# 2       147300000      2
# 3       147900000      3
# 4       128640000      4
# ...           ...    ...
# 10170  8855290000  10170
# 10171  7964830000  10171
# 10172  7654300000  10172
# 10173  7705590000  10173
# 10174  1031364000  10174
#
# [10175 rows x 7 columns]

# %%
fig = px.line(df, x='Date', y=["Close"])
fig.show()

# %% [markdown]
# ## TQQQ

# %%
data_3x = yf.Ticker(ETF_3x).history(
    period="max",
    interval="1d",
    auto_adjust=True,   # <-- IMPORTANT
    actions=False
)

# %% [markdown]
# data_3x =  pd.read_csv(f'QLD.csv', )

# %%
data_3x = data_3x.reset_index()
data_3x['id'] = data_3x.index
data_3x['Date'] = pd.to_datetime(data_3x['Date']).dt.date

# %%
data_3x.to_sql(
name='qld', 
con = conn,
if_exists='replace', 
index=False,
)
# Out:
# 4030

# %%
df = sql(u"""
select * 
from qld
order by Date asc
""")

fig = px.line(df, x='Date', y=["Close"])
fig.show()

# %%
df
# Out:
#             Date       Open       High        Low      Close     Volume    id
# 0     2010-02-11   0.194144   0.207514   0.193522   0.206396    6912000     0
# 1     2010-02-12   0.200780   0.209030   0.199612   0.207241   17203200     1
# 2     2010-02-16   0.212112   0.215765   0.208782   0.215268   19238400     2
# 3     2010-02-17   0.218151   0.218971   0.214870   0.218921   38361600     3
# 4     2010-02-18   0.218698   0.224389   0.217380   0.223072   77721600     4
# ...          ...        ...        ...        ...        ...        ...   ...
# 4025  2026-02-12  51.799999  52.070000  47.990002  48.259998  131150000  4025
# 4026  2026-02-13  48.150002  49.590000  47.180000  48.470001  123216600  4026
# 4027  2026-02-17  47.639999  48.980000  46.419998  48.349998  117089700  4027
# 4028  2026-02-18  48.529999  50.360001  48.200001  49.389999   81370800  4028
# 4029  2026-02-19  48.660999  49.400002  48.160000  48.830002   82597324  4029
#
# [4030 rows x 7 columns]

# %% [markdown]
# # daily percentage of QQQ

# %%
sql_to_table(
f"""
select qqq.*, 
pre_day.Date as pre_Date,
pre_day.Close as pre_Close,
(qqq.Close - pre_day.Close)/pre_day.Close AS Percent    
from qqq 
left join qqq as pre_day on pre_day.id+1 = qqq.id
order by qqq.Date asc
""",
'qqq'
)
# Out:
# 10175

# %%
sql(u"""
select * 
from qqq
order by Date asc
limit 2
""")
# Out:
#          Date        Open        High         Low       Close     Volume  id  \
# 0  1985-10-01  110.620003  112.160004  110.565002  112.139999  153160000   0
# 1  1985-10-02  112.139999  112.540001  110.779999  110.824997  164640000   1
#
#      pre_Date   pre_Close   Percent
# 0        None         NaN       NaN
# 1  1985-10-01  112.139999 -0.011726

# %%
sql(u"""
select * 
from qqq
order by Date desc
limit 2
""")
# Out:
#          Date          Open          High           Low         Close  \
# 0  2026-02-19  24771.652344  24890.117188  24690.869141  24797.339844
# 1  2026-02-18  24744.880859  25057.210938  24696.830078  24898.869141
#
#        Volume     id    pre_Date     pre_Close   Percent
# 0  1031364000  10174  2026-02-18  24898.869141 -0.004078
# 1  7705590000  10173  2026-02-17  24701.599609  0.007986

# %% [markdown]
# # simulation of daily leverage

# %%
data_list = sql(f"""
select 
Date,
Percent, 
{leverage_ratio}*Percent as Leveraged_Percent
from qqq
where Percent is not null
order by Date asc
""".format(leverage_ratio)).to_dict('records')

# %%
data_list[0:3]
# Out:
# [{'Date': '1985-10-02',
#   'Percent': -0.011726435246687159,
#   'Leveraged_Percent': -0.03517930574006148},
#  {'Date': '1985-10-03',
#   'Percent': 0.0004060978983005295,
#   'Leveraged_Percent': 0.0012182936949015886},
#  {'Date': '1985-10-04',
#   'Percent': -0.0071706122363594214,
#   'Leveraged_Percent': -0.021511836709078264}]

# %%
start_price = qqq['Close'][0]

qqq_price = start_price
tqqq_price = start_price

for r in data_list:
    ###
    qqq_price = qqq_price*(1+r['Percent'])
    r['price'] = qqq_price
    ###
    tqqq_price = tqqq_price*(1+r['Leveraged_Percent'])    
    r['Leveraged_price'] = tqqq_price  

data1 = pd.DataFrame(data_list)

# %%
data1.to_sql(
name='leveraged', 
con = conn,
if_exists='replace', 
index=False,
)
# Out:
# 10174

# %%
df = sql(u"""
select * 
from leveraged
order by Date asc
""")

fig = px.line(df, 
    x='Date', 
    y=[
    'price', 
    'Leveraged_price',
    ])
fig.show()

# %% [markdown]
# # regression

# %%
compare_3x = sql(u"""
select 
qld.Date,
leveraged.`Leveraged_price`,
qld.Close
from qld
join leveraged on leveraged.Date = qld.Date
order by qld.Date asc
""")

compare_3x.to_sql(
name='compare_3x', 
con = conn,
if_exists='replace', 
index=False,
)
# Out:
# 4030

# %%
X = compare_3x['Leveraged_price'].to_numpy()
X = np.array([[i] for i in X])
y = compare_3x['Close'].to_numpy()

# %%
reg = LinearRegression().fit(X, y)

# %%
reg.score(X, y)

print(reg.coef_)

print(reg.intercept_)
# Out:
# [0.00016497]
# 1.361991789371137

# %%
result = sql(f"""
select 
Date,
`Leveraged_price` * {reg.coef_[0]} + {reg.intercept_} AS simulated_Close,
Close
from compare_3x
""")

# %% [markdown]
# result.plot(x ='Date', y=[
#     'simulated_Close',
#     'Close',
#     ], grid = True)

# %%
fig = px.line(result, x='Date', y=["simulated_Close",'Close'])
fig.show()

# %% [markdown]
# # all simulation results

# %%
final_result = sql(f"""
select 
data1.Date,
data1.price AS {ETF},
data1.`Leveraged_price` * {reg.coef_[0]} + {reg.intercept_} AS simulated_{ETF_3x},
data_3x.Close as {ETF_3x}
from leveraged as data1
left join qld as data_3x 
on data_3x.Date = data1.Date
""")

# %%
fig = px.line(
final_result, x='Date', y=[
f'simulated_{ETF_3x}',
ETF_3x])
fig.show()

# %% [markdown]
# final_result.plot(x ='Date', y=[
#     'simulated_{}'.format(ETF_3x),
#     ETF_3x,
#     ], grid = True)

# %%
final_result.to_excel(
f'{ETF_3x}_simulation.xlsx',
index = False,
)

# %%
print(f'{ETF_3x}_simulation.xlsx')
# Out:
# TQQQ_simulation.xlsx

# %% [markdown]
# # simulated tqqq

# %%
df = sql(f"""
select Date, Leveraged_price
from leveraged
order by Date
""")

fig = px.line(
df, x='Date', y=['Leveraged_price'])
fig.show()

# %%
sql(f"""
select * 
from leveraged
limit 3
""")
# Out:
#          Date   Percent  Leveraged_Percent       price  Leveraged_price
# 0  1985-10-02 -0.011726          -0.035179  110.824997       108.194992
# 1  1985-10-03  0.000406           0.001218  110.870003       108.326805
# 2  1985-10-04 -0.007171          -0.021512  110.074997       105.996497

# %% [markdown]
# # retio of holding x years

# %%
def calculate_ratio(
    year = 1,
):

    df = sql(f"""
    with 

    a as (
    select a.Date as before_date, 
    b.Date as after_date,
    a.Leveraged_price as before_price_leveraged,
    b.Leveraged_price as after_price_leverage,
    a.price as before_price,
    b.price as after_price
    from leveraged as a 
    join leveraged as b
    on 
    Cast ((
        JulianDay(b.Date) - JulianDay(a.Date)
    ) As Integer) = {year} * 365
    )

    select before_date,
    after_date, 
    after_price/before_price as price_ratio,
    after_price_leverage/before_price_leveraged as price_ratio_leverage
    from a 
    """)

    df.to_sql(
    name='price_ratio', 
    con = conn,
    if_exists='replace', 
    index=False,
    )

    return {
        'holding_years':year,
        'qqq_return': sql(f"""
            select price_ratio
            from price_ratio
            """).median()[0] - 1, 
        'tqqq_return': sql(f"""
            select price_ratio_leverage
            from price_ratio
            """).median()[0] - 1
    }

# %%
# %%time

output = []

for year in [1, 2, 3, 5, 10, 15, 20, 25, 30]:
    output.append(calculate_ratio(year = year))
# Out:
# C:\Users\yanli\AppData\Local\Temp\ipykernel_24736\3827680635.py:39: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# C:\Users\yanli\AppData\Local\Temp\ipykernel_24736\3827680635.py:43: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# C:\Users\yanli\AppData\Local\Temp\ipykernel_24736\3827680635.py:39: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# C:\Users\yanli\AppData\Local\Temp\ipykernel_24736\3827680635.py:43: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# C:\Users\yanli\AppData\Local\Temp\ipykernel_24736\3827680635.py:39: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# C:\Users\yanli\AppData\Local\Temp\ipykernel_24736\3827680635.py:43: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# C:\Users\yanli\AppData\Local\Temp\ipykernel_24736\3827680635.py:39: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# C:\Users\yanli\AppData\Local\Temp\ipykernel_24736\3827680635.py:43: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# C:\Users\yanli\AppData\Local\Temp\ipykernel_24736\3827680635.py:39: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# C:\Users\yanli\AppData\Local\Temp\ipykernel_24736\3827680635.py:43: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# C:\Users\yanli\AppData\Local\Temp\ipykernel_24736\3827680635.py:39: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# C:\Users\yanli\AppData\Local\Temp\ipykernel_24736\3827680635.py:43: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# C:\Users\yanli\AppData\Local\Temp\ipykernel_24736\3827680635.py:39: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# C:\Users\yanli\AppData\Local\Temp\ipykernel_24736\3827680635.py:43: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`

# %%
return_df = pd.DataFrame(output)

# %%
return_df

# %%
return_df.to_excel(f'qqq_tqqq_return.xlsx', index = False)

# %% [markdown]
# # check the ration by all windows

# %%
sql(f"""
select *
from price_ratio
""")

# %%
df = sql(f"""
select * 
from price_ratio
""")

fig = px.line(
df, x='after_date', y=['price_ratio', 'price_ratio_leverage'])
fig.show()

# %% [markdown]
# # END
